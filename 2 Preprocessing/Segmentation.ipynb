# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip "/content/drive/MyDrive/BTP_AMRITAMAM/BandPass.zip" -d "/content/drive/MyDrive/BTP_AMRITAMAM/"
# Out:
# Archive:  /content/drive/MyDrive/BTP_AMRITAMAM/BandPass.zip
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A01/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A01/Testing/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A01/Training/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A02/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A02/Testing/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A02/Training/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A03/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A03/Testing/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A03/Training/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A04/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A04/Testing/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A04/Training/
#    creating: /content/drive/MyDrive/BTP_AMRITAMAM/BandPass/A05/
# ...

# %%
cd "/content/drive/MyDrive/BTP_AMRITAMAM/"
# Out:
# /content/drive/.shortcut-targets-by-id/1HAUgj9ICrfB46ME_Gce9FK26De_hM_Yv/BTP_AMRITAMAM

# %%
#made band pass filter generated csv file for every channel_setting csv file
import csv
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
from skimage import io
from scipy.signal import savgol_filter
from scipy.signal import butter,filtfilt
#import plotly.io as pio
import plotly.graph_objects as go
from scipy.signal import butter, lfilter
# importing os module   
import os  
    
def makeFolder(directory,parent_dir):
      # os.makedirs() method will raise  
      # an OSError if the directory  
      # to be created already exists  
          
      # Path  
      path = os.path.join(parent_dir, directory)  
          
      # Create the directory  
      # 'Nikhil'  
      os.makedirs(path)  
      print("Directory '% s' created" % directory) 
      return 1



#for all A01-9 folder
for folder in range(7,9):
    #for all A01T_1.csv-4 file
    for file in range(1,5):
        s = "A0" + str(folder) + "E_" + str(file);   #read file name
        readFile = "Channel_selection/A0"+ str(folder)+"/Testing/" + s  + ".csv"  #read file location
        saveDirectory = "Segmentation_after_channel_selection/A0"+str(folder)+"/Testing/"  #save location
        training = pd.read_csv(readFile)
        #makeFolder(s,saveDirectory)
        #print(training.shape[0])
        n = training.shape[0]
        i=0
        while (i<n):
          x = training[i:i+1000]
          fileName = int(i/1000)+1
          csvFile = saveDirectory + s + "/" + str(fileName) + ".csv"
          print(i,end=", ")
          x.to_csv(r"%s"%csvFile, index = False, header = True)
          i=i+1000
# Out:
# 0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000, 67000, 68000, 69000, 70000, 71000, 72000, 73000, 74000, 75000, 76000, 77000, 78000, 79000, 80000, 81000, 82000, 83000, 84000, 85000, 86000, 87000, 88000, 89000, 90000, 91000, 92000, 93000, 94000, 95000, 96000, 97000, 98000, 99000, 100000, 101000, 102000, 103000, 104000, 105000, 106000, 107000, 108000, 109000, 110000, 111000, 112000, 113000, 114000,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
