# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip "/content/drive/MyDrive/BTP_AMRITAMAM/BandPass.zip" -d "/content/drive/MyDrive/BTP_AMRITAMAM/Channel_selection/"

# %%
cd "/content/drive/MyDrive/BTP_AMRITAMAM/"
# Out:
# /content/drive/.shortcut-targets-by-id/1HAUgj9ICrfB46ME_Gce9FK26De_hM_Yv/BTP_AMRITAMAM

# %%
#made band pass filter generated csv file for every channel_setting csv file
import csv
import scipy.signal
import numpy as np
import pandas as pd
from skimage import io
import os  


#for all A01-9 folder
for folder in range(1,10):
    #for all A01T_1.csv-4 file
    for file in range(1,5):
        s = "A0" + str(folder) + "T_" + str(file);   #read file name
        readFile = "Filters/BandPass/A0"+ str(folder)+"/Training/bandPass" + s  + ".csv"  #read file location
        csvFile = "Channel_selection/A0"+str(folder)+"/Training/" + s + ".csv" #save location
        training = pd.read_csv(readFile)
        n = training.shape[0]
        i=0
        training_df = pd.DataFrame(training)
        selected_col_data = training[['1','2','4','5','8','10','12','19','21']]
        selected_col_data.to_csv(r"%s"%csvFile, index = False, header = True)
