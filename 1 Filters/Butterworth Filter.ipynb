# %%
#@title Butterworth filter
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from skimage import io
from scipy.signal import butter,filtfilt
import plotly.graph_objects as go

matplotlib.rc('figure', figsize=(35,7))

##step 2
s = "golayA01T_1.csv";
training = pd.read_csv(s)
print(training.shape[0])
# get columns to plot
li=[]
for i in range(1,23):
    li.append(str(i))
training.columns=li
columns = training.columns
data = training['4'][0:1000]
data = savgol_filter(data, 7, 3)

# Filter requirements.

fs = 2500.0       # sample rate, Hz
cutoff = 100    # desired cutoff frequency of the filter, Hz ,      slightly higher than actual 1.2 Hz
nyq = 0.5 * fs  # Nyquist Frequency
order = 2      # sin wave can be approx represented as quadratic
n =500 # total number of samples
T = n/fs         # Sample Period

##step 3
def butter_lowpass_filter(data, cutoff, fs, order):
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

##step 4
# Filter the data, and plot both the original and filtered signals.
y = butter_lowpass_filter(data, cutoff, fs, order)
fig = go.Figure()
fig.add_trace(go.Scatter(
            y = data,
            line =  dict(shape =  'spline' ),
            name = 'signal with noise'
            ))
fig.add_trace(go.Scatter(
            y = y,
            line =  dict(shape =  'spline' ),
            name = 'filtered signal, order=4'
            ))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-0f04804735d9> in <module>()
#      15 ##step 2
#      16 s = "golayA01T_1.csv";
# ---> 17 training = pd.read_csv(s)
#      18 print(training.shape[0])
#      19 # get columns to plot
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip "/content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/Training.zip" -d "/content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/"
# Out:
# Archive:  /content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/Training.zip
#   inflating: /content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/Training/golayA01T_1.csv
#   inflating: /content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/Training/golayA01T_2.csv
#   inflating: /content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/Training/golayA01T_3.csv
#   inflating: /content/drive/MyDrive/BTP_AMRITAMAM/Filters/golayResults/A01/Training/Training/golayA01T_4.csv

# %%
cd "/content/drive/MyDrive/BTP_AMRITAMAM/"
# Out:
# /content/drive/.shortcut-targets-by-id/1HAUgj9ICrfB46ME_Gce9FK26De_hM_Yv/BTP_AMRITAMAM

# %%
#made golay filter generated csv file for every channel_setting csv file
import csv
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
from skimage import io
from scipy.signal import savgol_filter
from scipy.signal import butter,filtfilt
#import plotly.io as pio
import plotly.graph_objects as go

matplotlib.rc('figure', figsize=(35,7))


# Filter requirements.

fs = 250.0       # sample rate, Hz
high_cutoff = 35    # desired cutoff frequency of the filter, Hz ,      slightly higher than actual 1.2 Hz
low_cutoff = 12
nyq = 0.5 * fs  # Nyquist Frequency
order = 2      # sin wave can be approx represented as quadratic
n =500 # total number of samples
T = n/fs         # Sample Period

##step 3
##step 3
def butter_highpass_filter(data, cutoff, fs, order):
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='high', analog=False)
    y = filtfilt(b, a, data)
    return y

def butter_lowpass_filter(data, cutoff, fs, order):
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y



#for all A01-9 folder
for folder in range(1,10):
    #for all A01T_1.csv-4 file
    for file in range(1,5):
        s = "A0" + str(folder) + "T_" + str(file) + ".csv";   #read file name
        readFile = "Filters/golayResults/A0"+ str(folder)+"/Training/golay" + s   #read file location
        saveDirectory = "Filters/Butterworth/A0"+str(folder)+"/Training/"  #save location
        training = pd.read_csv(readFile)
        x=training
        print(training.shape[0])
        print(training.shape[1])
        # get columns to plot
        li=[]
        for i in range(1,23):
            li.append(str(i))
        training.columns=li
        columns = training.columns
        
        # golay filter
        for column in columns:
            ##step 4
            # Filter the data, and plot both the original and filtered signals.
            y = butter_lowpass_filter(training[column], high_cutoff, fs, order)
            #y = butter_highpass_filter(y,low_cutoff,fs,order)

            training[column] = y
        
        csvFile = saveDirectory + "butter" + s
        print(csvFile)
        print("hi", training.shape[0])
        
        # save in a csv file 
        training.to_csv(r"%s"%csvFile, index = False, header = True)
# Out:
# 145078
# 22
# Filters/Butterworth/A01/Training/butterA01T_1.csv
# hi 145078
# 144954
# 22
# Filters/Butterworth/A01/Training/butterA01T_2.csv
# hi 144954
# 144483
# 22
# Filters/Butterworth/A01/Training/butterA01T_3.csv
# hi 144483
# 144379
# 22
# Filters/Butterworth/A01/Training/butterA01T_4.csv
# hi 144379
# 144867
# 22
# Filters/Butterworth/A02/Training/butterA02T_1.csv
# hi 144867
# 144683
# 22
# Filters/Butterworth/A02/Training/butterA02T_2.csv
# hi 144683
# 144623
# 22
# Filters/Butterworth/A02/Training/butterA02T_3.csv
# hi 144623
# 144721
# 22
# Filters/Butterworth/A02/Training/butterA02T_4.csv
# hi 144721
# 144867
# 22
# Filters/Butterworth/A03/Training/butterA03T_1.csv
# hi 144867
# 144683
# 22
# Filters/Butterworth/A03/Training/butterA03T_2.csv
# hi 144683
# 144623
# 22
# Filters/Butterworth/A03/Training/butterA03T_3.csv
# hi 144623
# 144721
# 22
# Filters/Butterworth/A03/Training/butterA03T_4.csv
# hi 144721
# 144828
# 22
# ...
